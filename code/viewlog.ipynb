# %%
import json
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
file_path = '../log/cadec_05-24_22-22-52.txt'
with open(file_path, 'r') as fp:
    data = fp.readlines()

# %%
train_loss = [0.0295, 0.0119, 0.0097,0.0084,0.0073, 0.0065, 0.0060, 0.0054, 0.0051, 0.0046]

# %%
matplotlib.rcParams.update({'font.size': 16})
plt.plot(range(len(train_loss)), train_loss)
plt.xlabel("Epoch")
plt.ylabel("Train Loss")
plt.grid()
# plt.legend()
plt.show()
